# %% [markdown]
# # Setup the StarGAN baseline model for training
# Purpose: To clone the repository and begin training the StarGAN-EVC model
#
# Assumptions:
#
# - Raw data (in the form of .wav files) has already been pre-processed into WORLD features by run_preprocessing.py
# - Pre-processed data is stored somewhere on Google Drive (can access here: https://drive.google.com/drive/folders/1UNdFseXfTQrGf_eT2E2GVVN28geNzxBG?usp=sharing)

# %% [markdown]
# # Clone the Repository
#
# Eric's repository is here: https://github.com/eric-zhizu/EmotionalConversionStarGAN
#
# It's a good idea to fork the repository so that you have your own copy that you can push to (and then pull request in order to merge with Eric's repository later).
#
# Another option if you don't want to fork is to create another branch, but you'll have to ask Eric for permission to push to his repository.

# %%
# A command the clears the output of a code cell
from IPython.display import clear_output

# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# You can replace this GitHub link with your forked repository if you want
# !git clone https://github.com/eric-zhizu/EmotionalConversionStarGAN.git
# !git checkout eric-implementation
clear_output()

# %%
# !pip install pyworld librosa

# %%
# %cd /content/
# !git clone https://github.com/speechbrain/speechbrain.git
# %cd speechbrain
# %pip install -r requirements.txt
# %pip install --editable .

# %% [markdown]
# # Download the Pre-processed Data
#
# Choose one out of two pre-processed datasets:
#
# - IEMOCAP
# - Emotional Speech Dataset
#
# Find the pre-processed data here: https://drive.google.com/drive/folders/1UNdFseXfTQrGf_eT2E2GVVN28geNzxBG?usp=sharing
#
# Move the desired preprocessed dataset into your Google Drive by right-clicking on the file and adding a shortcut to the file from the root directory of your Google Drive.
#
# Run the code below to move the file into your repository.

# %%
# %cd EmotionalConversionStarGAN/
# !unzip /content/gdrive/MyDrive/final_project/data/esd_ser_processed_data.zip

# %% [markdown]
# # Run the Training
# full_training_script.sh has three steps:
#
# 1) Run classifier_train.py for 100 epochs
#
# 2) Run train_main.py for 200,000 iterations (one iteration = one batch, not one epoch) just for reconstructing audio
#
# 3) Run train_main.py for 100,000 iterations for emotion conversion
#
# Adjust the hyperparameters in the .yaml files in configs/
#
# Here are some important arguments to train_main.py:
#
# ```
# python train_main.py
# --checkpoint <path/to/encoder-decoder-checkpoint>
# --load_emo <path/to/classifier-checkpoint>
# --config <path/to/config-file>
# --alter
# --recon_only
# ```
#
# ```
# Description of arguments
# checkpoint: load a generator/discriminator model
# load_emo: load a SER model
# config: load a .yaml file containing hyperparameters
# alter: if specified, will make the config file override the hyperparameters saved in checkpoint
# recon_only: if specified, will ignore the classifier and train the model to reconstruct the audio in the same emotion
# ```

# %%
# %cd EmotionalConversionStarGAN
# Out:
# /content/EmotionalConversionStarGAN

# %%
# !pip install librosa pyworld tensorflow==1.15
clear_output()

# %%
# !bash full_training_script.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# Training Generator...
# D/total_loss         = -0.9153
# G/total_loss         = 0.5071
# D/gradient_penalty   = 0.0048
# G/loss_cycle         = 0.0074
# G/loss_id            = 0.0074
# D/preds_real         = 0.4695
# D/preds_fake         = -0.4700
# No model saved this iteration.
# 12:16:32.335783 elapsed. Iteration 199625 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199626/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199626 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:32.394973 elapsed. Iteration 199626 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199627/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199627 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:32.572398 elapsed. Iteration 199627 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199628/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199628 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:32.749639 elapsed. Iteration 199628 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199629/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199629 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:32.927593 elapsed. Iteration 199629 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199630/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199630 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = 0.0668
# G/total_loss         = -0.4394
# D/gradient_penalty   = 0.0075
# G/loss_cycle         = 0.0077
# G/loss_id            = 0.0077
# D/preds_real         = 0.4486
# D/preds_fake         = 0.4779
# No model saved this iteration.
# 12:16:33.418750 elapsed. Iteration 199630 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199631/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199631 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:33.477950 elapsed. Iteration 199631 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199632/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199632 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:33.655058 elapsed. Iteration 199632 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199633/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199633 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:33.833647 elapsed. Iteration 199633 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199634/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199634 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:34.011251 elapsed. Iteration 199634 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199635/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199635 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -1.4040
# G/total_loss         = 0.5239
# D/gradient_penalty   = 0.0038
# G/loss_cycle         = 0.0071
# G/loss_id            = 0.0073
# D/preds_real         = 0.9351
# D/preds_fake         = -0.4878
# No model saved this iteration.
# 12:16:34.502264 elapsed. Iteration 199635 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199636/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199636 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:34.561734 elapsed. Iteration 199636 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199637/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199637 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:34.739055 elapsed. Iteration 199637 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199638/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199638 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:34.916490 elapsed. Iteration 199638 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199639/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199639 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:35.093681 elapsed. Iteration 199639 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199640/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199640 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -0.9182
# G/total_loss         = 0.0508
# D/gradient_penalty   = 0.0022
# G/loss_cycle         = 0.0070
# G/loss_id            = 0.0072
# D/preds_real         = 0.9135
# D/preds_fake         = -0.0157
# No model saved this iteration.
# 12:16:35.584960 elapsed. Iteration 199640 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199641/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199641 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:35.644400 elapsed. Iteration 199641 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199642/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199642 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:35.821496 elapsed. Iteration 199642 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199643/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199643 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:35.999037 elapsed. Iteration 199643 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199644/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199644 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:36.176386 elapsed. Iteration 199644 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199645/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199645 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = 0.5361
# G/total_loss         = -0.9299
# D/gradient_penalty   = 0.0014
# G/loss_cycle         = 0.0071
# G/loss_id            = 0.0075
# D/preds_real         = 0.4374
# D/preds_fake         = 0.9663
# No model saved this iteration.
# 12:16:36.667080 elapsed. Iteration 199645 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199646/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199646 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:36.726922 elapsed. Iteration 199646 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199647/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199647 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:36.904623 elapsed. Iteration 199647 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199648/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199648 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:37.081724 elapsed. Iteration 199648 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199649/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199649 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:37.259359 elapsed. Iteration 199649 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199650/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199650 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -0.4576
# G/total_loss         = 0.0432
# D/gradient_penalty   = 0.0009
# G/loss_cycle         = 0.0073
# G/loss_id            = 0.0075
# D/preds_real         = 0.4561
# D/preds_fake         = -0.0062
# No model saved this iteration.
# 12:16:37.750101 elapsed. Iteration 199650 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199651/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199651 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:37.809457 elapsed. Iteration 199651 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199652/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199652 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:37.987031 elapsed. Iteration 199652 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199653/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199653 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:38.164888 elapsed. Iteration 199653 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199654/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199654 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:38.342717 elapsed. Iteration 199654 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199655/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199655 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -0.9119
# G/total_loss         = 0.5182
# D/gradient_penalty   = 0.0053
# G/loss_cycle         = 0.0071
# G/loss_id            = 0.0074
# D/preds_real         = 0.4566
# D/preds_fake         = -0.4820
# No model saved this iteration.
# 12:16:38.833574 elapsed. Iteration 199655 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199656/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199656 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:38.892878 elapsed. Iteration 199656 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199657/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199657 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:39.070278 elapsed. Iteration 199657 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199658/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199658 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:39.247498 elapsed. Iteration 199658 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199659/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199659 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:39.424988 elapsed. Iteration 199659 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199660/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199660 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -1.4221
# G/total_loss         = 0.5217
# D/gradient_penalty   = 0.0008
# G/loss_cycle         = 0.0085
# G/loss_id            = 0.0086
# D/preds_real         = 0.9473
# D/preds_fake         = -0.4789
# No model saved this iteration.
# 12:16:39.915910 elapsed. Iteration 199660 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199661/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199661 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:39.975452 elapsed. Iteration 199661 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199662/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199662 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:40.152699 elapsed. Iteration 199662 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199663/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199663 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:40.329914 elapsed. Iteration 199663 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199664/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199664 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:40.507236 elapsed. Iteration 199664 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199665/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199665 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -0.4562
# G/total_loss         = 0.0299
# D/gradient_penalty   = 0.0010
# G/loss_cycle         = 0.0063
# G/loss_id            = 0.0064
# D/preds_real         = 0.4632
# D/preds_fake         = 0.0019
# No model saved this iteration.
# 12:16:40.997973 elapsed. Iteration 199665 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199666/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199666 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:41.058280 elapsed. Iteration 199666 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199667/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199667 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:41.235485 elapsed. Iteration 199667 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199668/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199668 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:41.412556 elapsed. Iteration 199668 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199669/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199669 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:41.589746 elapsed. Iteration 199669 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199670/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199670 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -0.9277
# G/total_loss         = 0.0498
# D/gradient_penalty   = 0.0017
# G/loss_cycle         = 0.0075
# G/loss_id            = 0.0079
# D/preds_real         = 0.9246
# D/preds_fake         = -0.0114
# No model saved this iteration.
# 12:16:42.081332 elapsed. Iteration 199670 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199671/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199671 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:42.141314 elapsed. Iteration 199671 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199672/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199672 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:42.318441 elapsed. Iteration 199672 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199673/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199673 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:42.495613 elapsed. Iteration 199673 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199674/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199674 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:42.673435 elapsed. Iteration 199674 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199675/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199675 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = 0.0684
# G/total_loss         = -0.4464
# D/gradient_penalty   = 0.0064
# G/loss_cycle         = 0.0070
# G/loss_id            = 0.0072
# D/preds_real         = 0.4453
# D/preds_fake         = 0.4818
# No model saved this iteration.
# 12:16:43.164251 elapsed. Iteration 199675 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199676/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199676 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:43.223955 elapsed. Iteration 199676 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199677/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199677 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:43.401399 elapsed. Iteration 199677 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199678/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199678 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:43.578557 elapsed. Iteration 199678 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199679/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199679 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:43.755885 elapsed. Iteration 199679 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199680/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199680 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -0.9220
# G/total_loss         = 0.0423
# D/gradient_penalty   = 0.0009
# G/loss_cycle         = 0.0073
# G/loss_id            = 0.0074
# D/preds_real         = 0.9210
# D/preds_fake         = -0.0055
# No model saved this iteration.
# 12:16:44.247045 elapsed. Iteration 199680 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199681/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199681 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:44.306937 elapsed. Iteration 199681 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199682/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199682 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:44.484287 elapsed. Iteration 199682 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199683/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199683 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:44.661818 elapsed. Iteration 199683 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199684/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199684 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:44.839105 elapsed. Iteration 199684 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199685/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199685 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -0.4259
# G/total_loss         = 0.0397
# D/gradient_penalty   = 0.0065
# G/loss_cycle         = 0.0076
# G/loss_id            = 0.0078
# D/preds_real         = 0.4571
# D/preds_fake         = -0.0012
# No model saved this iteration.
# 12:16:45.330223 elapsed. Iteration 199685 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199686/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199686 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:45.389804 elapsed. Iteration 199686 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199687/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199687 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:45.567156 elapsed. Iteration 199687 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199688/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199688 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:45.744384 elapsed. Iteration 199688 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199689/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199689 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:45.921721 elapsed. Iteration 199689 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199690/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199690 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -1.4376
# G/total_loss         = 0.5245
# D/gradient_penalty   = 0.0014
# G/loss_cycle         = 0.0092
# G/loss_id            = 0.0093
# D/preds_real         = 0.9665
# D/preds_fake         = -0.4782
# No model saved this iteration.
# 12:16:46.412825 elapsed. Iteration 199690 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199691/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199691 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:46.472265 elapsed. Iteration 199691 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199692/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199692 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:46.649489 elapsed. Iteration 199692 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199693/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199693 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:46.826739 elapsed. Iteration 199693 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199694/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199694 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:47.004373 elapsed. Iteration 199694 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199695/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199695 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -1.4193
# G/total_loss         = 0.5181
# D/gradient_penalty   = 0.0028
# G/loss_cycle         = 0.0083
# G/loss_id            = 0.0083
# D/preds_real         = 0.9568
# D/preds_fake         = -0.4766
# No model saved this iteration.
# 12:16:47.495271 elapsed. Iteration 199695 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199696/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199696 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:47.554871 elapsed. Iteration 199696 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199697/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199697 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:47.732310 elapsed. Iteration 199697 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199698/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199698 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:47.909788 elapsed. Iteration 199698 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199699/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199699 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:48.086905 elapsed. Iteration 199699 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199700/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199700 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -0.4417
# G/total_loss         = -0.4408
# D/gradient_penalty   = 0.0013
# G/loss_cycle         = 0.0076
# G/loss_id            = 0.0078
# D/preds_real         = 0.9272
# D/preds_fake         = 0.4793
# No model saved this iteration.
# 12:16:48.577871 elapsed. Iteration 199700 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199701/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199701 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:48.637425 elapsed. Iteration 199701 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199702/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199702 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:48.814481 elapsed. Iteration 199702 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199703/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199703 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:48.991970 elapsed. Iteration 199703 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199704/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199704 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:49.169671 elapsed. Iteration 199704 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199705/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199705 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -0.9605
# G/total_loss         = 1.0059
# D/gradient_penalty   = 0.0015
# G/loss_cycle         = 0.0068
# G/loss_id            = 0.0069
# D/preds_real         = -0.0037
# D/preds_fake         = -0.9716
# No model saved this iteration.
# 12:16:49.660460 elapsed. Iteration 199705 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199706/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199706 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:49.719965 elapsed. Iteration 199706 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199707/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199707 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:49.897176 elapsed. Iteration 199707 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199708/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199708 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:50.074606 elapsed. Iteration 199708 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199709/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199709 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:50.251905 elapsed. Iteration 199709 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199710/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199710 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -1.4176
# G/total_loss         = 0.5206
# D/gradient_penalty   = 0.0009
# G/loss_cycle         = 0.0076
# G/loss_id            = 0.0076
# D/preds_real         = 0.9393
# D/preds_fake         = -0.4828
# No model saved this iteration.
# 12:16:50.742823 elapsed. Iteration 199710 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199711/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199711 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:50.801993 elapsed. Iteration 199711 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199712/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199712 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:50.978965 elapsed. Iteration 199712 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199713/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199713 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:51.156537 elapsed. Iteration 199713 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199714/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199714 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:51.333987 elapsed. Iteration 199714 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199715/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199715 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -0.9245
# G/total_loss         = 0.0461
# D/gradient_penalty   = 0.0021
# G/loss_cycle         = 0.0074
# G/loss_id            = 0.0075
# D/preds_real         = 0.9262
# D/preds_fake         = -0.0087
# No model saved this iteration.
# 12:16:51.824941 elapsed. Iteration 199715 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199716/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199716 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:51.884805 elapsed. Iteration 199716 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199717/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199717 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:52.062072 elapsed. Iteration 199717 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199718/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199718 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:52.239339 elapsed. Iteration 199718 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199719/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199719 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:52.416558 elapsed. Iteration 199719 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199720/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199720 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -0.9156
# G/total_loss         = 0.5247
# D/gradient_penalty   = 0.0085
# G/loss_cycle         = 0.0078
# G/loss_id            = 0.0077
# D/preds_real         = 0.4721
# D/preds_fake         = -0.4860
# No model saved this iteration.
# 12:16:52.907738 elapsed. Iteration 199720 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199721/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199721 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:52.966970 elapsed. Iteration 199721 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199722/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199722 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:53.144421 elapsed. Iteration 199722 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199723/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199723 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:53.322248 elapsed. Iteration 199723 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199724/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199724 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:16:53.499690 elapsed. Iteration 199724 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199725/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199725 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# ...
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:47.305763 elapsed. Iteration 199972 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199973/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199973 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:47.482955 elapsed. Iteration 199973 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199974/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199974 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:47.660305 elapsed. Iteration 199974 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199975/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199975 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -0.4581
# G/total_loss         = 0.5325
# D/gradient_penalty   = 0.0019
# G/loss_cycle         = 0.0082
# G/loss_id            = 0.0083
# D/preds_real         = -0.0238
# D/preds_fake         = -0.4913
# No model saved this iteration.
# 12:17:48.151053 elapsed. Iteration 199975 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199976/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199976 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:48.210959 elapsed. Iteration 199976 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199977/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199977 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:48.387974 elapsed. Iteration 199977 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199978/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199978 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:48.566877 elapsed. Iteration 199978 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199979/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199979 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:48.744453 elapsed. Iteration 199979 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199980/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199980 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = 0.0500
# G/total_loss         = -0.4443
# D/gradient_penalty   = 0.0028
# G/loss_cycle         = 0.0075
# G/loss_id            = 0.0077
# D/preds_real         = 0.4461
# D/preds_fake         = 0.4822
# No model saved this iteration.
# 12:17:49.235379 elapsed. Iteration 199980 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199981/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199981 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:49.294598 elapsed. Iteration 199981 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199982/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199982 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:49.471966 elapsed. Iteration 199982 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199983/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199983 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:49.649450 elapsed. Iteration 199983 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199984/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199984 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:49.826755 elapsed. Iteration 199984 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199985/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199985 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -0.4542
# G/total_loss         = 0.0393
# D/gradient_penalty   = 0.0007
# G/loss_cycle         = 0.0068
# G/loss_id            = 0.0071
# D/preds_real         = 0.4531
# D/preds_fake         = -0.0047
# No model saved this iteration.
# 12:17:50.318341 elapsed. Iteration 199985 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199986/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199986 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:50.378053 elapsed. Iteration 199986 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199987/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199987 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:50.555271 elapsed. Iteration 199987 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199988/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199988 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:50.732729 elapsed. Iteration 199988 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199989/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199989 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:50.909982 elapsed. Iteration 199989 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199990/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199990 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -0.4300
# G/total_loss         = 0.0455
# D/gradient_penalty   = 0.0023
# G/loss_cycle         = 0.0075
# G/loss_id            = 0.0077
# D/preds_real         = 0.4337
# D/preds_fake         = -0.0078
# No model saved this iteration.
# 12:17:51.401409 elapsed. Iteration 199990 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199991/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199991 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:51.460984 elapsed. Iteration 199991 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199992/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199992 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:51.639669 elapsed. Iteration 199992 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199993/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199993 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:51.817177 elapsed. Iteration 199993 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199994/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199994 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:51.994281 elapsed. Iteration 199994 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199995/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199995 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = -0.4364
# G/total_loss         = 0.0457
# D/gradient_penalty   = 0.0058
# G/loss_cycle         = 0.0079
# G/loss_id            = 0.0080
# D/preds_real         = 0.4595
# D/preds_fake         = -0.0060
# No model saved this iteration.
# 12:17:52.485181 elapsed. Iteration 199995 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199996/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199996 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:52.544420 elapsed. Iteration 199996 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199997/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199997 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:52.721766 elapsed. Iteration 199997 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199998/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199998 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:52.898952 elapsed. Iteration 199998 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 199999/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 199999 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# No Generator update this iteration.
# No log output this iteration.
# No model saved this iteration.
# 12:17:53.077577 elapsed. Iteration 199999 complete
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Iteration 200000/200000 ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Iteration 200000 lr = 0.000000
# Device is  cuda
# Classifier device is  cuda
# Getting mini-batch.
# solver.train: x_real size = torch.Size([4, 1, 512, 36])
# No classifier training this run.
# Training Discriminator...
# Training Generator...
# D/total_loss         = 0.0364
# G/total_loss         = 0.0399
# D/gradient_penalty   = 0.0031
# G/loss_cycle         = 0.0069
# G/loss_id            = 0.0071
# D/preds_real         = -0.0261
# D/preds_fake         = -0.0049
# Model saved as ./checkpoints/model_step1/200000.ckpt.
# Testing generator accuracy ...
# /content/EmotionalConversionStarGAN/stargan/classifiers.py:69: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   x_lens = x_lens//8    # seq_len have got ~4 times shorted
# Accuracy_real        = 0.402
# Accuracy_fake        = 0.340
# Accuracy_id          = 0.402
# Accuracy_cycle       = 0.402
# L1_id                = 0.008
# L1_cycle             = 0.007
# Saving world samples...
# 12:17:58.423530 elapsed. Iteration 200000 complete
# Model saved as ./checkpoints/model_step1/200000.ckpt.
# True
# 1.10.0+cu111
# <module 'torch.cuda' from '/usr/local/lib/python3.7/dist-packages/torch/cuda/__init__.py'>
# Using WORLD features.
# Data directory =  ./processed_data/world
# 2435  files used.
# Training samples: 2191
# Test samples: 244
# Performing whole network training.
# Building components
# Building optimizers
# WARNING:tensorflow:From /content/EmotionalConversionStarGAN/stargan/logger.py:21: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Made logger.
# ./checkpoints/model_step1/200000.ckpt
# Model and optimizers loaded.
# Made logger.
# Traceback (most recent call last):
#   File "train_main.py", line 155, in <module>
#     s.model.load_pretrained_classifier(args.load_emo, map_location='cpu')
#   File "/content/EmotionalConversionStarGAN/stargan/model.py", line 255, in load_pretrained_classifier
#     dictionary = torch.load(load_dir, map_location=map_location)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 594, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: './checkpoints/cls_checkpoint.ckpt'

# %% [markdown]
# # Evaluate Model

# %%
# !git pull origin eric-implementation
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/eric-zhizu/EmotionalConversionStarGAN
#  * branch            eric-implementation -> FETCH_HEAD
#    f99024d..4178032  eric-implementation -> origin/eric-implementation
# Updating f99024d..4178032
# Fast-forward
#  convert.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# Convert .wav ==> input features
# Pass into the model
# Output features
### TO ADD: compare output features with input features ==> evaluate the model
# Converts output features ==> .wav
# %cd /content/EmotionalConversionStarGAN
# !python convert.py --checkpoint /content/gdrive/MyDrive/final_project/checkpoints/esd_trial_checkpoints_02/model_step2/300000.ckpt -o processed_data/converted
# Out:
# /content/EmotionalConversionStarGAN
# Loading model at  /content/gdrive/MyDrive/final_project/checkpoints/esd_trial_checkpoints_02/model_step2/300000.ckpt
# Building components
# Building optimizers
# /content/gdrive/MyDrive/final_project/checkpoints/esd_trial_checkpoints_02/model_step2/300000.ckpt
# Model and optimizers loaded.
# Number of emotions = 4
# Converting train and test samples in ./processed_data/audio
# 27988  files used.
# /content/EmotionalConversionStarGAN/utils/audio_utils.py:67: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   wav = wavfile.read(path)[1]
# Warning: Incomplete wav chunk. file 0018_000594.wav
# Converting 0015_000693 to 0.
# Converting 0015_000693 to 1.
# Converting 0015_000693 to 2.
# Converting 0015_000693 to 3.
# Converting 0013_001351 to 0.
# Converting 0013_001351 to 1.
# Converting 0013_001351 to 2.
# Converting 0013_001351 to 3.
# Converting 0013_000900 to 0.
# Converting 0013_000900 to 1.
# Converting 0013_000900 to 2.
# Converting 0013_000900 to 3.
# Converting 0013_000631 to 0.
# Converting 0013_000631 to 1.
# Converting 0013_000631 to 2.
# Converting 0013_000631 to 3.
# Converting 0015_001308 to 0.
# Converting 0015_001308 to 1.
# Converting 0015_001308 to 2.
# Converting 0015_001308 to 3.
# Converting 0018_001226 to 0.
# Converting 0018_001226 to 1.
# Converting 0018_001226 to 2.
# Converting 0018_001226 to 3.
# Converting 0018_000217 to 0.
# Converting 0018_000217 to 1.
# Converting 0018_000217 to 2.
# Converting 0018_000217 to 3.
# Converting 0013_001022 to 0.
# Converting 0013_001022 to 1.
# Converting 0013_001022 to 2.
# Converting 0013_001022 to 3.
# Converting 0016_000449 to 0.
# Converting 0016_000449 to 1.
# Converting 0016_000449 to 2.
# Traceback (most recent call last):
#   File "convert.py", line 255, in <module>
#     convert_files(train_wav_files, "train")
#   File "convert.py", line 244, in convert_files
#     audio_utils.save_world_wav([f0,ap,sp,converted_sp], filename_wav)
#   File "/content/EmotionalConversionStarGAN/utils/audio_utils.py", line 276, in save_world_wav
#     wav = synthesize(feats[0], decoded_sp, feats[1], hp.sr)
# KeyboardInterrupt

# %%
# !cp -r processed_data/converted /content/gdrive/MyDrive/final_project/data/esd_trial_conversion_02
